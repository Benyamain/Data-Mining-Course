# %%
# imports
import pandas as pd

data = pd.read_csv('C:/Users/yacoo/DataMiningCourse/Assignments/Assignment-Three/aaup.csv', header=None)
data.columns = ['Univ_id', 'Univ_name', 'State', 'Type', 'fp_sal', 'ac_sal', 'at_sal', 'to_sal', 'fp_com', 'ac_com', 'at_com', 'to_com', 'fp_#', 'ac_#', 'at_#', 'in_#', 'to_#']

# contains the row
print('Number of observations = %d' % (data.shape[0]))
# contains the column
print('Number of attributes = %d' % (data.shape[1]))

# show the first 100 values across all attributes
data.head(100)
# Out:
# Number of observations = 1161
# Number of attributes = 17
#     Univ_id                    Univ_name State Type fp_sal ac_sal at_sal  \
# 0      1061    Alaska Pacific University    AK  IIB    454    382    362
# 1      1063        Univ.Alaska-Fairbanks    AK    I    686    560    432
# 2      1065        Univ.Alaska-Southeast    AK  IIA    533    494    329
# 3     11462        Univ.Alaska-Anchorage    AK  IIA    612    507    414
# 4      1002    Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310
# ..      ...                          ...   ...  ...    ...    ...    ...
# 95     3948    San Francisco State Univ.    CA  IIA    599    483    397
# 96     7993      Cal.St.Univ-Bakersfield    CA  IIA    597    482    377
# 97    10395      University of San Diego    CA  IIA    719    533    452
# 98    11649  Loyola Marymount University    CA  IIA    722    558    414
# 99     1345          Adams State College    CO  IIA    436    356    321
#
# ...

# %%
import numpy as np

# recode missing values of '*' into 'NaN'
data = data.replace('*', np.NaN)

# contains the row
print('Number of observations = %d' % (data.shape[0]))
# contains the column
print('Number of attributes = %d' % (data.shape[1]))

print('Number of missing values across the attributes:')
for col in data.columns:
    print('\t%s: %d' % (col,data[col].isna().sum()))
# Out:
# Number of observations = 1161
# Number of attributes = 17
# Number of missing values across the attributes:
# 	Univ_id: 0
# 	Univ_name: 0
# 	State: 0
# 	Type: 0
# 	fp_sal: 68
# 	ac_sal: 36
# 	at_sal: 24
# 	to_sal: 0
# 	fp_com: 68
# 	ac_com: 36
# 	at_com: 24
# 	to_com: 0
# 	fp_#: 0
# 	ac_#: 0
# 	at_#: 0
# 	in_#: 0
# 	to_#: 0

# %%
# list
columns_with_missing = ['fp_sal', 'ac_sal', 'at_sal', 'fp_com', 'ac_com', 'at_com']

print('Before dropping missing values:')
for col in columns_with_missing:
    print(data[col][35:40])
    
print('\nNumber of rows in original data = %d' % (data.shape[0]))
data.dropna(subset=columns_with_missing, inplace=True)

print('\nAfter dropping missing values:')
for col in columns_with_missing:
    print(data[col][35:40])

print('\nNumber of rows after dropping missing values = %d' % (data.shape[0]))
# Out:
# Before dropping missing values:
# 35    536
# 36    422
# 37    NaN
# 38    461
# 39    563
# Name: fp_sal, dtype: object
# 35    416
# 36    355
# 37    NaN
# 38    389
# 39    436
# Name: ac_sal, dtype: object
# 35    372
# 36    289
# 37    264
# 38    321
# 39    379
# Name: at_sal, dtype: object
# 35    651
# 36    529
# 37    NaN
# 38    575
# 39    686
# Name: fp_com, dtype: object
# 35    506
# 36    445
# 37    NaN
# 38    484
# 39    531
# Name: ac_com, dtype: object
# 35    450
# 36    375
# 37    327
# 38    402
# 39    461
# Name: at_com, dtype: object
#
# Number of rows in original data = 1161
#
# After dropping missing values:
# 36    422
# 38    461
# 39    563
# 40    424
# 41    358
# Name: fp_sal, dtype: object
# 36    355
# 38    389
# 39    436
# 40    374
# 41    328
# Name: ac_sal, dtype: object
# 36    289
# 38    321
# 39    379
# 40    335
# 41    274
# Name: at_sal, dtype: object
# 36    529
# 38    575
# 39    686
# 40    512
# 41    439
# ...

# %%
# inline import
# %matplotlib inline

# boxplot
data.boxplot(figsize=(10,10))

# %%
# return boolean series denoting duplicate rows
dups = data.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

# show the first 10 values across all attributes
data.head(10)
# Out:
# Number of duplicate rows = 0
#    Univ_id                    Univ_name State Type fp_sal ac_sal at_sal  \
# 0     1061    Alaska Pacific University    AK  IIB    454    382    362
# 1     1063        Univ.Alaska-Fairbanks    AK    I    686    560    432
# 2     1065        Univ.Alaska-Southeast    AK  IIA    533    494    329
# 3    11462        Univ.Alaska-Anchorage    AK  IIA    612    507    414
# 4     1002    Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310
# 5     1004     University of Montevallo    AL  IIA    441    385    310
# 6     1008         Athens State College    AL  IIB    466    394    351
# 7     1009      Auburn University- Main    AL    I    580    437    374
# 8     1012  Birmingham Southern College    AL  IIB    498    379    322
# 9     1016       Univ. of North Alabama    AL  IIB    506    412    359
#
#    to_sal fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 0     382    567    485    471     487     6    11     9     4    32
# ...

# %%
# aggregating the institutions within their respective state they reside in
states = data.groupby('State')
print('The number of states found: ', states.ngroups)
print('\nThe number of institutions within each state: ', states.size())

# computing mean for salary and compensation
# ?? should i combine all of the things
print('\nThe mean: ', states[columns_with_missing].mean())
# Out:
# The number of states found:  52
#
# The number of institutions within each state:  State
# AK     4
# AL    21
# AR    14
# AZ     4
# CA    52
# CO    14
# CT    15
# DC     8
# DE     3
# FL    19
# GA    21
# HI     2
# IA    24
# ID     5
# IL    45
# IN    36
# KS    17
# KY    20
# LA    19
# MA    41
# MD    21
# ME    12
# MI    28
# MN    25
# MO    29
# MS    11
# MT     8
# NC    38
# ND     5
# NE    14
# NH    11
# NJ    22
# NM     5
# NV     2
# NY    77
# OH    46
# OK    16
# OR    15
# PA    81
# RI     7
# SC    22
# SD     8
# TN    26
# TX    51
# UT     6
# VA    38
# VT     9
# WA    14
# WI    26
# WV    15
# WW     1
# WY     1
# dtype: int64
#
# The mean:                fp_sal         ac_sal         at_sal         fp_com  \
# State
# AK      1.136716e+11   9.564012e+10   9.060808e+10   1.419787e+11
# AL      2.106864e+61   1.758978e+61   1.477668e+61   2.526393e+61
# AR      3.238617e+40   2.595474e+40   2.359517e+40   4.010754e+40
# ...

# %%
# just to get an idea
data.head()
# Out:
#    Univ_id                  Univ_name State Type fp_sal ac_sal at_sal  to_sal  \
# 0     1061  Alaska Pacific University    AK  IIB    454    382    362     382
# 1     1063      Univ.Alaska-Fairbanks    AK    I    686    560    432     508
# 2     1065      Univ.Alaska-Southeast    AK  IIA    533    494    329     415
# 3    11462      Univ.Alaska-Anchorage    AK  IIA    612    507    414     498
# 4     1002  Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310     350
#
#   fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 0    567    485    471     487     6    11     9     4    32
# 1    914    753    572     677    74   125   118    40   404
# 2    716    663    442     559     9    26    20     9    70
# 3    825    681    557     670   115   124   101    21   392
# 4    530    444    376     423    59    77   102    24   262

# %%
# sampling w/o replacement
sample = data.sample(n=5)
sample
# Out:
#      Univ_id                   Univ_name State Type fp_sal ac_sal at_sal  \
# 972     3490             Fisk University    TN  IIB    383    369    269
# 656     4741  Rutgers State Univ.-Camden    NJ  IIA    860    633    510
# 868     3284           Lafayette College    PA  IIB    686    517    419
# 767     3048          Heidelberg College    OH  IIB    399    334    298
# 227     1671           DePaul University    IL  IIA    702    543    427
#
#      to_sal fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 972     319    451    437    314     375    17    19    17     2    65
# 656     648   1060    805    664     820    61    73    61     6   206
# 868     506    873    668    536     647    37    62    71     8   179
# 767     331    491    407    349     397    17    18    24     8    67
# 227     524    857    681    527     648   120   173   152    55   500

# %%
# sampling w/o replacement but considering to look at 1% of the dataset
sample = data.sample(frac=0.01, random_state=1)
sample
# Out:
#       Univ_id                     Univ_name State Type fp_sal ac_sal at_sal  \
# 691      2731   Hobart-William Smith Colls.    NY  IIB    605    462    352
# 461      2273                  Hope College    MI  IIB    515    420    350
# 51       1139        Cal.St.Univ-Long Beach    CA  IIA    600    474    401
# 216      1621     Lewis-Clark State College    ID  IIB    391    329    292
# 1080     3752    Virginia Intermont College    VA  IIB    332    318    279
# 83       1317      Univ.of Calif.-San Diego    CA    I    723    487    401
# 372      2118            Assumption College    MA  IIB    479    400    325
# 574      2928      Fayetteville State Univ.    NC  IIA    525    437    375
# 381      2140  Coll.of Our Lady of the Elms    MA  IIB    431    353    305
# 200      1879           Morningside College    IA  IIB    389    331    303
# 802     12748      Shawnee State University    OH  IIB    510    439    368
#
# ...

# %%
# sampling with replacement
sample = data.sample(frac=0.01, replace=True, random_state=1)
sample
# Out:
#       Univ_id                    Univ_name State Type fp_sal ac_sal at_sal  \
# 1148     3811     Davis and Elkins College    WV  IIB    373    305    259
# 252      1741   Olivet Nazarene University    IL  IIA    391    335    278
# 984      3527             Tusculum College    TN  IIB    353    327    290
# 777      3086              Oberlin College    OH  IIB    588    454    385
# 919      3987             La Roche College    PA  IIB    433    364    302
# 1039    11161  Texas A&M U.-Corpus Christi    TX  IIA    475    396    334
# 152      1531           Stetson University    FL  IIA    622    437    370
# 135      1448            Howard University    DC    I    656    483    403
# 815      3175          Phillips University    OK  IIB    365    315    273
# 551      2440    University of Mississippi    MS    I    558    428    384
# 384      2153               Gordon College    MA  IIB    432    352    319
#
# ...

# %%
"""
for some odd reason, numeric attributes were not being 'detected' as they should have 
and therefore were converted to that
"""
data['fp_sal'] = pd.to_numeric(data['fp_sal'])

# histogram scaled out that shows all the data
print(data['fp_sal'].value_counts(sort=False))
data['fp_sal'].hist(bins=10)
# Out:
# 454    2
# 686    3
# 533    5
# 612    2
# 442    4
#       ..
# 655    1
# 678    1
# 501    2
# 333    1
# 535    2
# Name: fp_sal, Length: 423, dtype: int64

# %%
# discretize the attributes using equal width method
bins = pd.cut(data['fp_sal'], 5)
print(bins.value_counts(sort=False))
# showing what it would mean to discretize the bins into categorical attributes
data['fp_sal'].hist(bins=5)
# Out:
# (269.261, 417.8]    183
# (417.8, 565.6]      543
# (565.6, 713.4]      274
# (713.4, 861.2]       63
# (861.2, 1009.0]      11
# Name: fp_sal, dtype: int64

# %%
# discretize the attributes using equal frequency method
bins = pd.qcut(data['fp_sal'], 3)
print(bins.value_counts(sort=False))
# showing what it would mean to discretize the bins with nearly same number of instances
data['fp_sal'].hist(bins=3)
# Out:
# (269.999, 465.667]    358
# (465.667, 562.0]      360
# (562.0, 1009.0]       356
# Name: fp_sal, dtype: int64

# %%
data['fp_#'] = pd.to_numeric(data['fp_#'])

# histogram scaled out that shows all the data
print(data['fp_#'].value_counts(sort=False))
data['fp_#'].hist(bins=10)
# Out:
# 6      11
# 74      3
# 9      22
# 115     2
# 59      8
#        ..
# 893     1
# 337     1
# 918     1
# 167     1
# 335     1
# Name: fp_#, Length: 292, dtype: int64

# %%
bins = pd.cut(data['fp_#'], 5)
print(bins.value_counts(sort=False))
data['fp_#'].hist(bins=5)
# Out:
# (5.009, 204.2]    927
# (204.2, 402.4]     85
# (402.4, 600.6]     42
# (600.6, 798.8]     11
# (798.8, 997.0]      9
# Name: fp_#, dtype: int64

# %%
bins = pd.qcut(data['fp_#'], 3)
print(bins.value_counts(sort=False))
data['fp_#'].hist(bins=3)
# Out:
# (5.999, 28.0]    368
# (28.0, 80.0]     350
# (80.0, 997.0]    356
# Name: fp_#, dtype: int64
