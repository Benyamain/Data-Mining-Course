# %%
# imports
import pandas as pd

data = pd.read_csv('C:/Users/yacoo/DataMiningCourse/Assignments/Assignment-Three/aaup.csv', header=None)
data.columns = ['Univ_id', 'Univ_name', 'State', 'Type', 'fp_sal', 'ac_sal', 'at_sal', 'to_sal', 'fp_com', 'ac_com', 'at_com', 'to_com', 'fp_#', 'ac_#', 'at_#', 'in_#', 'to_#']

# contains the row
print('Number of observations = %d' % (data.shape[0]))
# contains the column
print('Number of attributes = %d' % (data.shape[1]))

# show the first 100 values across all attributes
data.head(100)
# Out:
# Number of observations = 1161
# Number of attributes = 17
#     Univ_id                    Univ_name State Type fp_sal ac_sal at_sal  \
# 0      1061    Alaska Pacific University    AK  IIB    454    382    362
# 1      1063        Univ.Alaska-Fairbanks    AK    I    686    560    432
# 2      1065        Univ.Alaska-Southeast    AK  IIA    533    494    329
# 3     11462        Univ.Alaska-Anchorage    AK  IIA    612    507    414
# 4      1002    Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310
# ..      ...                          ...   ...  ...    ...    ...    ...
# 95     3948    San Francisco State Univ.    CA  IIA    599    483    397
# 96     7993      Cal.St.Univ-Bakersfield    CA  IIA    597    482    377
# 97    10395      University of San Diego    CA  IIA    719    533    452
# 98    11649  Loyola Marymount University    CA  IIA    722    558    414
# 99     1345          Adams State College    CO  IIA    436    356    321
#
# ...

# %%
import numpy as np

# recode missing values of '*' into 'NaN'
data = data.replace('*',np.NaN)

# contains the row
print('Number of observations = %d' % (data.shape[0]))
# contains the column
print('Number of attributes = %d' % (data.shape[1]))

print('Number of missing values across the attributes:')
for col in data.columns:
    print('\t%s: %d' % (col,data[col].isna().sum()))
# Out:
# Number of observations = 1161
# Number of attributes = 17
# Number of missing values across the attributes:
# 	Univ_id: 0
# 	Univ_name: 0
# 	State: 0
# 	Type: 0
# 	fp_sal: 68
# 	ac_sal: 36
# 	at_sal: 24
# 	to_sal: 0
# 	fp_com: 68
# 	ac_com: 36
# 	at_com: 24
# 	to_com: 0
# 	fp_#: 0
# 	ac_#: 0
# 	at_#: 0
# 	in_#: 0
# 	to_#: 0

# %%
# list
columns_with_missing = ['fp_sal', 'ac_sal', 'at_sal', 'fp_com', 'ac_com', 'at_com']

print('Before dropping missing values:')
for col in columns_with_missing:
    print(data[col][35:40])
    
print('\nNumber of rows in original data = %d' % (data.shape[0]))
data.dropna(subset=columns_with_missing, inplace=True)

print('\nAfter dropping missing values:')
for col in columns_with_missing:
    print(data[col][35:40])

print('\nNumber of rows after dropping missing values = %d' % (data.shape[0]))
# Out:
# Before dropping missing values:
# 35    536
# 36    422
# 37    NaN
# 38    461
# 39    563
# Name: fp_sal, dtype: object
# 35    416
# 36    355
# 37    NaN
# 38    389
# 39    436
# Name: ac_sal, dtype: object
# 35    372
# 36    289
# 37    264
# 38    321
# 39    379
# Name: at_sal, dtype: object
# 35    651
# 36    529
# 37    NaN
# 38    575
# 39    686
# Name: fp_com, dtype: object
# 35    506
# 36    445
# 37    NaN
# 38    484
# 39    531
# Name: ac_com, dtype: object
# 35    450
# 36    375
# 37    327
# 38    402
# 39    461
# Name: at_com, dtype: object
#
# Number of rows in original data = 1161
#
# After dropping missing values:
# 36    422
# 38    461
# 39    563
# 40    424
# 41    358
# Name: fp_sal, dtype: object
# 36    355
# 38    389
# 39    436
# 40    374
# 41    328
# Name: ac_sal, dtype: object
# 36    289
# 38    321
# 39    379
# 40    335
# 41    274
# Name: at_sal, dtype: object
# 36    529
# 38    575
# 39    686
# 40    512
# 41    439
# ...

# %%
# inline import
# %matplotlib inline

# boxplot
data.boxplot(figsize=(10,10))

# %%
# return boolean series denoting duplicate rows
dups = data.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

# show the first 10 values across all attributes
data.head(10)
# Out:
# Number of duplicate rows = 0
#    Univ_id                    Univ_name State Type fp_sal ac_sal at_sal  \
# 0     1061    Alaska Pacific University    AK  IIB    454    382    362
# 1     1063        Univ.Alaska-Fairbanks    AK    I    686    560    432
# 2     1065        Univ.Alaska-Southeast    AK  IIA    533    494    329
# 3    11462        Univ.Alaska-Anchorage    AK  IIA    612    507    414
# 4     1002    Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310
# 5     1004     University of Montevallo    AL  IIA    441    385    310
# 6     1008         Athens State College    AL  IIB    466    394    351
# 7     1009      Auburn University- Main    AL    I    580    437    374
# 8     1012  Birmingham Southern College    AL  IIB    498    379    322
# 9     1016       Univ. of North Alabama    AL  IIB    506    412    359
#
#    to_sal fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 0     382    567    485    471     487     6    11     9     4    32
# ...

# %%
# aggregating the institutions within their respective state they reside in
states = data.groupby('State')
print('The number of states found: ', states.ngroups)

# computing mean
states[columns_with_missing].mean()
# Out:
# The number of states found:  52
#               fp_sal         ac_sal         at_sal         fp_com  \
# State
# AK      1.136716e+11   9.564012e+10   9.060808e+10   1.419787e+11
# AL      2.106864e+61   1.758978e+61   1.477668e+61   2.526393e+61
# AR      3.238617e+40   2.595474e+40   2.359517e+40   4.010754e+40
# AZ      8.965088e+10   8.211236e+10   6.859984e+10   1.099309e+11
# CA     8.277999e+153  7.218649e+153  6.121223e+153  1.103043e+157
# CO      3.118668e+40   2.546346e+40   2.295702e+40   3.769833e+40
# CT      4.444131e+43   3.563077e+43   2.649110e+43   5.712073e+44
# DC      9.332645e+22   6.505619e+22   5.217317e+22   1.122149e+24
# DE      1.819078e+08   1.451771e+08   1.198074e+08   2.389742e+08
# FL      2.570729e+55   2.213065e+55   1.843954e+55   3.150108e+55
# GA      2.511640e+61   2.006645e+61   1.696835e+61   3.102755e+61
# HI      3.567880e+05   2.662305e+05   2.292070e+05   4.438655e+05
# IA      1.531185e+70   1.351735e+70   1.193081e+70   1.973361e+70
# ...

# %%
# just to get an idea
data.head()
# Out:
#    Univ_id                  Univ_name State Type fp_sal ac_sal at_sal  to_sal  \
# 0     1061  Alaska Pacific University    AK  IIB    454    382    362     382
# 1     1063      Univ.Alaska-Fairbanks    AK    I    686    560    432     508
# 2     1065      Univ.Alaska-Southeast    AK  IIA    533    494    329     415
# 3    11462      Univ.Alaska-Anchorage    AK  IIA    612    507    414     498
# 4     1002  Alabama Agri.&Mech. Univ.    AL  IIA    442    369    310     350
#
#   fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 0    567    485    471     487     6    11     9     4    32
# 1    914    753    572     677    74   125   118    40   404
# 2    716    663    442     559     9    26    20     9    70
# 3    825    681    557     670   115   124   101    21   392
# 4    530    444    376     423    59    77   102    24   262

# %%
# sampling w/o replacement
sample_without_replacement = data.sample(n=3)
sample_without_replacement
# Out:
#       Univ_id                 Univ_name State Type fp_sal ac_sal at_sal  \
# 1097     3692        Norwich University    VT  IIA    423    356    297
# 745      6791  SUNY College at Purchase    NY  IIB    534    432    362
# 880      3313        Widener University    PA  IIA    670    556    439
#
#       to_sal fp_com ac_com at_com  to_com  fp_#  ac_#  at_#  in_#  to_#
# 1097     371    545    468    394     484    62    51    32     1   146
# 745      437    696    565    468     570    29    52    28     0   114
# 880      529    870    714    567     683    60   136    88    18   309

# %%
sample_without_replacement = data.sample(frac=0.01, random_state=1)
sample_without_replacement
# Out:
#       Univ_id                     Univ_name State Type fp_sal ac_sal at_sal  \
# 691      2731   Hobart-William Smith Colls.    NY  IIB    605    462    352
# 461      2273                  Hope College    MI  IIB    515    420    350
# 51       1139        Cal.St.Univ-Long Beach    CA  IIA    600    474    401
# 216      1621     Lewis-Clark State College    ID  IIB    391    329    292
# 1080     3752    Virginia Intermont College    VA  IIB    332    318    279
# 83       1317      Univ.of Calif.-San Diego    CA    I    723    487    401
# 372      2118            Assumption College    MA  IIB    479    400    325
# 574      2928      Fayetteville State Univ.    NC  IIA    525    437    375
# 381      2140  Coll.of Our Lady of the Elms    MA  IIB    431    353    305
# 200      1879           Morningside College    IA  IIB    389    331    303
# 802     12748      Shawnee State University    OH  IIB    510    439    368
#
# ...

# %% [markdown]
# Finally, we perform a sampling with replacement to create a sample whose size is equal to 1% of the entire data. You should be able to observe duplicate instances in the sample by increasing the sample size.
#
# **<font color="red">Code:</font>**

# %%
# sampling with replacement
sample_with_replacement = data.sample(frac=0.01, replace=True, random_state=1)
sample
# Out:
#      Clump Thickness  Uniformity of Cell Size  ...  Mitoses  Class
# 37                 6                        2  ...        1      2
# 235                3                        1  ...        1      2
# 72                 1                        3  ...        1      2
# 645                3                        1  ...        1      2
# 144                2                        1  ...        1      2
# 129                1                        1  ...        1      2
# 583                3                        1  ...        1      2
#
# [7 rows x 10 columns]

# %% [markdown]
# ## 4.4 Discretization
#
# Discretization is a data preprocessing step that is often used to transform a continuous-valued attribute to a categorical attribute. The example below illustrates two simple but widely-used unsupervised discretization methods (equal width and equal depth) applied to the 'Clump Thickness' attribute of the breast cancer dataset.

# %% [markdown]
# First, we plot a histogram that shows the distribution of the attribute values. The value_counts() function can also be applied to count the frequency of each attribute value.
#
# **<font color="red">Code:</font>**

# %%
data['Clump Thickness'].hist(bins=10)
data['Clump Thickness'].value_counts(sort=False)
# Out:
# 1     145
# 2      50
# 3     108
# 4      80
# 5     130
# 6      34
# 7      23
# 8      46
# 9      14
# 10     69
# Name: Clump Thickness, dtype: int64

# %% [markdown]
# For the equal width method, we can apply the cut() function to discretize the attribute into 4 bins of similar interval widths. The value_counts() function can be used to determine the number of instances in each bin.
#
# **<font color="red">Code:</font>**

# %%
bins = pd.cut(data['Clump Thickness'],4)
bins.value_counts(sort=False)
# Out:
# (0.991, 3.25]    303
# (3.25, 5.5]      210
# (5.5, 7.75]       57
# (7.75, 10.0]     129
# Name: Clump Thickness, dtype: int64

# %% [markdown]
# For the equal frequency method, the qcut() function can be used to partition the values into 4 bins such that each bin has nearly the same number of instances.
#
# **<font color="red">Code:</font>**

# %%
bins = pd.qcut(data['Clump Thickness'],4)
bins.value_counts(sort=False)
# Out:
# (0.999, 2.0]    195
# (2.0, 4.0]      188
# (4.0, 6.0]      164
# (6.0, 10.0]     152
# Name: Clump Thickness, dtype: int64
